# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('../DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
img2 = cv2.imread('wrong_path/hehe')

# %%
type(img2)
# Out:
# NoneType

# %%
plt.imshow(img)

# %%
#because OpenCV thinks of image for Blue, Green, Red and Matplotlib thinks of image for Red, Green, Blue

# %%
fix_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_image)

# %%
img_gray = cv2.imread('../DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray)

# %%
#just say cmap to show gray picture

# %%
plt.imshow(img_gray, cmap = 'gray')

# %%
plt.imshow(fix_image)

# %%
plt.imshow(cv2.resize(img, (400, 400)))

# %%
w_ratio = 2
h_ratio = 1

# %%
new_img = cv2.resize(fix_image, (0,0), fix_image, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (1300, 3900, 3)

# %%
new_img = cv2.flip(fix_image, 1)
plt.imshow(new_img)

# %%
cv2.imwrite('new_image.jpg', new_img)
# Out:
# True

# %%
fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot(111)
ax.imshow(fix_image)
